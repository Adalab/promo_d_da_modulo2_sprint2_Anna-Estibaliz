# %% [markdown]
# # Pair Programming Limpieza II - Strings

# %%
import pandas as pd
import numpy as np

from scipy import stats 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data

# %%
df = pd.read_csv("datos/bank-additional-full.csv", index_col=0)

# %% [markdown]
# Hipótesis
#
# - La edad, el trabajo, el estado civil, la educación, la situación de deuda y la forma de contacto pueden influir en la probabilidad de que un cliente acepte la oferta.
#
# - El número de veces que se ha contactado a un cliente en el pasado (campo campaign), el número de días que han pasado desde el último contacto (campo pdays), y el resultado de la campaña anterior (campo poutcome) pueden afectar la respuesta del cliente a una nueva oferta.
#
# - Las variables económicas (tales como el índice de precios al consumidor (cons.price.idx), la tasa de variación del empleo (emp.var.rate), etc.) pueden influir en la probabilidad de que un cliente acepte la oferta.
#
# - Los clientes que ya tienen una hipoteca (housing) o un préstamo (loan) pueden ser menos propensos a aceptar una nueva oferta, ya que podrían estar limitados financieramente.

# %%
df.head(2)
# Out:
#    age        job  marital    education  default  housing  loan    contact  \
# 0   56  housemaid  married     basic.4y      0.0      0.0   0.0  telephone
# 1   57   services  married  high.school      NaN      0.0   0.0  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp,var,rate  \
# 0       261         1    999         0  NONEXISTENT           1.1
# 1       149         1    999         0  NONEXISTENT           1.1
#
#    cons,price,idx  cons,conf,idx  euribor3m  nr,employed   y  month_day_week
# 0          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 1          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default           float64
# housing           float64
# loan              float64
# contact            object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp,var,rate      float64
# cons,price,idx    float64
# cons,conf,idx     float64
# euribor3m         float64
# nr,employed       float64
# y                  object
# month_day_week     object
# dtype: object

# %% [markdown]
# Por lo tanto, en este ejercicio nos queda por limpiar algunas columnas del conjunto de datos, así que manos a la obra. Vamos a ver que podemos hacer para cada una de las columnas y os dejaremos algunas pistas 😉.
#
# Para esto trabajaremos con el fichero generado en Limpieza I.
#
# - Columnas loan, housing y default: estas columnas contienen valores únicos de 0 y 1. Esto puede parecer poco intuitivo a la hora de la extracción de conclusiones y en las visualizaciones. El objetivo de este ejercicio es que cambies los valores númericos por "Si" y "No". A que corresponde cada uno de los valores lo tenéis en el pair de Limpieza I.

# %%
df['default'] = pd.cut(df['default'], 2, labels= ['Si', 'No'])

# %%
df['housing'] = pd.cut(df['housing'], 2, right=True, labels= ['Si', 'No'])
df['loan'] = pd.cut(df['loan'], 2, right=True, labels= ['Si', 'No'])

# %%
df.sample(10)
# Out:
#        age          job   marital          education default housing loan  \
# 39302   56      retired   married           basic.4y      Si      Si   Si
# 22260   51   management   married  university.degree      Si      No   Si
# 26975   50   unemployed       NaN           basic.9y      Si      Si   Si
# 19690   48  blue-collar   married           basic.4y     NaN      Si   Si
# 3752    28  blue-collar   married           basic.9y      Si      No   Si
# 2059    54   management  divorced  university.degree      Si      Si   Si
# 39433   49       admin.   married        high.school     NaN      Si   Si
# 32618   26       admin.    single  university.degree      Si      Si   Si
# 8221    36   management   married  university.degree     NaN      Si   Si
# 32193   47  blue-collar   married        high.school      Si      Si   No
#
#          contact  duration  campaign  pdays  previous     poutcome  \
# 39302   cellular       181         2      9         2      FAILURE
# ...

# %%
pr='professional.course'	

pr.split('.')
# Out:
# ['professional', 'course']

# %% [markdown]
# - Para la columna de education, si nos fijamos en sus valores únicos veremos que tenemos puntos. El objetivo de este ejercicio es que quitéis los puntos de esos valores y los reemplacéis por espacios.

# %%
df['education'] = df['education'].str.replace('.', ' ')
# Out:
# /tmp/ipykernel_1160/2890631216.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['education'] = df['education'].str.replace('.', ' ')

# %% [markdown]
# Hemos creado la función y el apply para tener de ejemplo otro método.

# %%
# def reemplazar(columna):
#     try:
#         return columna.replace('.', ' ')
#     except:
#         return np.nan

# %%
# df['education'] = df['education'].apply(reemplazar)

# %%
df.head(5)
# Out:
#    age        job  marital    education default housing loan    contact  \
# 0   56  housemaid  married     basic 4y      Si      Si   Si  telephone
# 1   57   services  married  high school     NaN      Si   Si  telephone
# 2   37   services  married  high school      Si      No   Si  telephone
# 3   40     admin.  married     basic 6y      Si      Si   Si  telephone
# 4   56   services  married  high school      Si      Si   No  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp,var,rate  \
# 0       261         1    999         0  NONEXISTENT           1.1
# 1       149         1    999         0  NONEXISTENT           1.1
# 2       226         1    999         0  NONEXISTENT           1.1
# 3       151         1    999         0  NONEXISTENT           1.1
# 4       307         1    999         0  NONEXISTENT           1.1
#
#    cons,price,idx  cons,conf,idx  euribor3m  nr,employed   y  month_day_week
# ...

# %% [markdown]
# - Para la columna job, hay un valor único que esta abreviado (admin.), cambiad la abreviatura por el nombre completo.

# %%
df['job'].unique()
# Out:
# array(['housemaid', 'services', 'admin.', 'blue-collar', 'technician',
#        'retired', 'management', 'unemployed', 'self-employed', nan,
#        'entrepreneur', 'student'], dtype=object)

# %%
df['job'] = df['job'].str.replace('admin.', 'administration')
# Out:
# /tmp/ipykernel_1160/1492269935.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['job'] = df['job'].str.replace('admin.', 'administration')

# %% [markdown]
# - La columna month_day_week tiene una lista que contiene información muy diferente. El objetivo de este ejercicio es separar esta columna en dos nuevas, donde tengamos los meses en una columna y los días de la semana en otra.

# %%
df[['month', 'weekday']] = df['month_day_week'].str.split(',', n=2, expand=True)

# %%
df['month'] = df['month'].str.replace('[', ' ')
# Out:
# /tmp/ipykernel_1160/3813751538.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['month'] = df['month'].str.replace('[', ' ')

# %%
df['weekday'] = df['weekday'].str.replace(']', ' ')
# Out:
# /tmp/ipykernel_1160/1733631987.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['weekday'] = df['weekday'].str.replace(']', ' ')

# %% [markdown]
# Buscar patron de regex para que nos capture las tres letras del string y nos quite los corchetes

# %%
df.head(3)
# Out:
#    age        job  marital    education default housing loan    contact  \
# 0   56  housemaid  married     basic 4y      Si      Si   Si  telephone
# 1   57   services  married  high school     NaN      Si   Si  telephone
# 2   37   services  married  high school      Si      No   Si  telephone
#
#    duration  campaign  ...     poutcome  emp,var,rate cons,price,idx  \
# 0       261         1  ...  NONEXISTENT           1.1         93.994
# 1       149         1  ...  NONEXISTENT           1.1         93.994
# 2       226         1  ...  NONEXISTENT           1.1         93.994
#
#    cons,conf,idx  euribor3m  nr,employed   y  month_day_week   month  weekday
# 0          -36.4      4.857       5191.0  no  ['may', 'mon']   'may'   'mon'
# 1          -36.4      4.857       5191.0  no  ['may', 'mon']   'may'   'mon'
# 2          -36.4      4.857       5191.0  no  ['may', 'mon']   'may'   'mon'
#
# [3 rows x 22 columns]

# %% [markdown]
# Guarda el csv con las columnas limpias para seguir trabajando con este dataframe limpio.

# %%
df.to_csv("datos/bank-additional-full.csv")
